# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
#Loading Dataset into DataFrame
df = pd.read_csv("Academic.csv")
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12        NaN      M     IT        75.0       64.0       67.0
# ...

# %%
#Preprocessing
df.isnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0    False  False   False   False       False      False      False
# 1    False  False   False   False       False      False      False
# 2    False  False   False   False       False      False      False
# 3    False  False   False   False       False      False      False
# 4    False  False   False   False       False      False       True
# 5    False  False   False   False       False      False      False
# 6    False  False   False   False       False      False      False
# 7    False  False   False   False       False      False      False
# 8    False  False   False   False       False       True       True
# 9    False  False   False   False       False      False      False
# 10   False  False   False   False       False      False      False
# 11   False   True   False   False       False      False      False
# 12   False  False   False   False       False      False      False
# ...

# %%
# Handling NaN values
mean_value = df['Che_marks'].mean()
df['Che_marks'].fillna(mean_value, inplace=True)
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0   98.000000
# 1        2    Reyansh      M     IT        58.0       62.0   83.000000
# 2        3      Aarav      M     IT        57.0      -20.0  100.000000
# 3        4     Atharv      M     IT        60.0       89.0   83.000000
# 4        5     Vivaan      M   Comp        85.0       90.0   80.764706
# 5        6      Advik      M   ENTC        94.0       99.0   84.000000
# 6        7       Ansh      M   ENTC        98.0       88.0   95.000000
# 7        8     Ishaan      M   ENTC        75.0       66.0   51.000000
# 8        9      Dhruv      M   ENTC        63.0        NaN   80.764706
# 9       10  Siddharth      M   ENTC        96.0       67.0   78.000000
# 10      11     Vihaan      M   ENTC        82.0       54.0   70.000000
# 11      12        NaN      M     IT        75.0       64.0   67.000000
# ...

# %%
#preprocessing
df.describe()
# Out:
#          Rollno  Attendence  Phy_marks   Che_marks   EM1_marks  PPS_marks  \
# count  20.00000   20.000000  19.000000   20.000000   18.000000  19.000000
# mean   10.50000   75.100000  63.421053   80.764706   83.444444  60.736842
# std     5.91608   14.660724  34.940133   12.563646   11.078449  43.598983
# min     1.00000   53.000000 -34.000000   51.000000   63.000000 -99.000000
# 25%     5.75000   63.750000  59.000000   76.000000   75.750000  56.000000
# 50%    10.50000   73.000000  67.000000   81.000000   83.000000  66.000000
# 75%    15.25000   87.000000  88.000000   86.250000   93.000000  87.500000
# max    20.00000   98.000000  99.000000  100.000000  100.000000  99.000000
#
#        SME_marks  Total Marks  Percentage
# count  20.000000    20.000000   20.000000
# mean   62.700000   327.150000   65.430000
# std    24.891554    78.951867   15.790373
# min    23.000000   192.000000   38.400000
# 25%    42.750000   279.750000   55.950000
# 50%    60.500000   338.000000   67.600000
# ...

# %%
#Preprocessing
df.shape
# Out:
# (20, 12)

# %%
#preprocessing
df.dtypes
# Out:
# Rollno           int64
# Name            object
# Gender          object
# Branch          object
# Attendence     float64
# Phy_marks      float64
# Che_marks      float64
# EM1_marks      float64
# PPS_marks      float64
# SME_marks      float64
# Total Marks      int64
# Percentage     float64
# dtype: object

# %%
#Data Formatting
df['Name'] = df['Name'].astype('string')
df.dtypes
# Out:
# Rollno                  int64
# Name           string[python]
# Gender                 object
# Branch                 object
# Attendence            float64
# Phy_marks             float64
# Che_marks             float64
# EM1_marks             float64
# PPS_marks             float64
# SME_marks             float64
# Total Marks             int64
# Percentage            float64
# dtype: object

# %%
#Normalization
columns_to_normalize = ['SME_marks']
for column in columns_to_normalize:
    max_value = df[column].max()
    df[column] = df[column] / max_value

# %%
df[["SME_marks"]].head()
# Out:
#    SME_marks
# 0   0.363636
# 1   0.343434
# 2   0.363636
# 3   0.232323
# 4   0.565657

# %%
#Caegorial into Quantitative Data
df['Gender']=df['Gender'].map({'M':0,'F':1}).astype(float)

df
# Out:
#     Rollno       Name  Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed     0.0   Comp        72.0       62.0   98.000000
# 1        2    Reyansh     0.0     IT        58.0       62.0   83.000000
# 2        3      Aarav     0.0     IT        57.0      -20.0  100.000000
# 3        4     Atharv     0.0     IT        60.0       89.0   83.000000
# 4        5     Vivaan     0.0   Comp        85.0       90.0   80.764706
# 5        6      Advik     0.0   ENTC        94.0       99.0   84.000000
# 6        7       Ansh     0.0   ENTC        98.0       88.0   95.000000
# 7        8     Ishaan     0.0   ENTC        75.0       66.0   51.000000
# 8        9      Dhruv     0.0   ENTC        63.0        NaN   80.764706
# 9       10  Siddharth     0.0   ENTC        96.0       67.0   78.000000
# 10      11     Vihaan     0.0   ENTC        82.0       54.0   70.000000
# 11      12       <NA>     0.0     IT        75.0       64.0   67.000000
# ...
